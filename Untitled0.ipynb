# %% [markdown]
# <a href="https://colab.research.google.com/github/rishikesh0787/TODO-APP2/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import sklearn

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/Dataset/MensT20wcdata.csv')
df.head
# Out:
# <bound method NDFrame.head of     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# 21        22  South Africa    Bangladesh
# ...

# %%
df1.fillna(130, inplace = True)

# %%
df1
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# 21        22  South Africa    Bangladesh
# ...

# %%
column='Score_of_first_innings'
df1[column]= (df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/array_ops.py in _na_arithmetic_op(left, right, op, is_cmp)
#     165     try:
# --> 166         result = func(left, right)
#     167     except TypeError:
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-19-9c10acebcbc0> in <module>
#       1 column='Score_of_first_innings'
# ----> 2 df1[column]= (df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
#       3 display(df1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
# ...

# %%
df.Score_of_first_innings=df.Score_of_first_innings.str.replace('-','NaN')
df
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# 21        22  South Africa    Bangladesh
# ...

# %%
# select the rows
# if Name column
# has special characters
print(df[df.Score_of_first_innings.str.contains(r'[@#&$%+-/*]')])
# Out:
# Empty DataFrame
# Columns: [Match_id, Team_1, Team_2,              Venue, Stage, Toss_winner, Toss_decision, Score_of_first_innings, Wkts_in_first_innings, Score_of_second_innings, Wkts_in_second_innings, Winner, Won by, Player_of_the_match]
# Index: []

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/business-financial-data-june-2022-quarter-csv.csv")

# %%
df
# Out:
#      BDCQ.SF1AA2CA  2016.06  1116.386  Unnamed: 3  F  Dollars  6  \
# 0    BDCQ.SF1AA2CA  2016.09  1070.874         NaN  F  Dollars  6
# 1    BDCQ.SF1AA2CA  2016.12  1054.408         NaN  F  Dollars  6
# 2    BDCQ.SF1AA2CA  2017.03  1010.665         NaN  F  Dollars  6
# 3    BDCQ.SF1AA2CA  2017.06  1233.700         NaN  F  Dollars  6
# 4    BDCQ.SF1AA2CA  2017.09  1282.436         NaN  F  Dollars  6
# ..             ...      ...       ...         ... ..      ... ..
# 327   BDCQ.SF1BBCS  2017.03  1040.500         NaN  R  Dollars  6
# 328   BDCQ.SF1BBCS  2017.06  1150.976         NaN  R  Dollars  6
# 329   BDCQ.SF1BBCS  2017.09  1084.658         NaN  R  Dollars  6
# 330   BDCQ.SF1BBCS  2017.12  1352.840         NaN  R  Dollars  6
# 331   BDCQ.SF1BBCS  2018.03  1224.534         NaN  R  Dollars  6
#
#      Business Data Collection - BDC  \
# 0    Business Data Collection - BDC
# 1    Business Data Collection - BDC
# 2    Business Data Collection - BDC
# ...

# %%
df1=df.dropna()

# %%
df
# Out:
#      BDCQ.SF1AA2CA  2016.06  1116.386  Unnamed: 3  F  Dollars  6  \
# 0    BDCQ.SF1AA2CA  2016.09  1070.874         NaN  F  Dollars  6
# 1    BDCQ.SF1AA2CA  2016.12  1054.408         NaN  F  Dollars  6
# 2    BDCQ.SF1AA2CA  2017.03  1010.665         NaN  F  Dollars  6
# 3    BDCQ.SF1AA2CA  2017.06  1233.700         NaN  F  Dollars  6
# 4    BDCQ.SF1AA2CA  2017.09  1282.436         NaN  F  Dollars  6
# ..             ...      ...       ...         ... ..      ... ..
# 327   BDCQ.SF1BBCS  2017.03  1040.500         NaN  R  Dollars  6
# 328   BDCQ.SF1BBCS  2017.06  1150.976         NaN  R  Dollars  6
# 329   BDCQ.SF1BBCS  2017.09  1084.658         NaN  R  Dollars  6
# 330   BDCQ.SF1BBCS  2017.12  1352.840         NaN  R  Dollars  6
# 331   BDCQ.SF1BBCS  2018.03  1224.534         NaN  R  Dollars  6
#
#      Business Data Collection - BDC  \
# 0    Business Data Collection - BDC
# 1    Business Data Collection - BDC
# 2    Business Data Collection - BDC
# ...

# %%
df1.head()
# Out:
# Empty DataFrame
# Columns: [BDCQ.SF1AA2CA, 2016.06, 1116.386, Unnamed: 3, F, Dollars, 6, Business Data Collection - BDC, Industry by financial variable (NZSIOC Level 2), Sales (operating income), Forestry and Logging, Current prices, Unadjusted]
# Index: []

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/MensT20wcdata.csv")

# %%
df
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# 21        22  South Africa    Bangladesh
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 21        22  South Africa    Bangladesh
# 22        23         India  Netherlands
# ...

# %%
df=pd.read_csv("/content/drive/MyDrive/Dataset/MensT20wcdata.csv")
df
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 20        21   Afghanistan   New Zealand
# 21        22  South Africa    Bangladesh
# ...

# %%
df1=df.dropna()

# %%
df1
# Out:
#     Match_id        Team_1        Team_2  \
# 0          1       Namibia     Sri Lanka
# 1          2           UAE  Netherlands
# 2          3      Scotland   West Indies
# 3          4       Zimbave       Ireland
# 4          5       Namibia  Netherlands
# 5          6     Sri Lanka           UAE
# 6          7      Scotland       Ireland
# 7          8   West Indies       Zimbave
# 8          9     Sri Lanka  Netherlands
# 9         10           UAE       Namibia
# 10        11   West Indies       Ireland
# 11        12      Scotland       Zimbave
# 12        13   New Zealand     Australia
# 13        14   Afghanistan       England
# 14        15       Ireland     Sri Lanka
# 15        16      Pakistan         India
# 16        17    Bangladesh  Netherlands
# 17        18       Zimbave  South Africa
# 18        19     Sri Lanka     Australia
# 19        20       Ireland       England
# 21        22  South Africa    Bangladesh
# 22        23         India  Netherlands
# ...

# %%
column='Match_id'
df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Match_id        Team_1        Team_2  \
# 0   0.000000       Namibia     Sri Lanka
# 1   0.022727           UAE  Netherlands
# 2   0.045455      Scotland   West Indies
# 3   0.068182       Zimbave       Ireland
# 4   0.090909       Namibia  Netherlands
# 5   0.113636     Sri Lanka           UAE
# 6   0.136364      Scotland       Ireland
# 7   0.159091   West Indies       Zimbave
# 8   0.181818     Sri Lanka  Netherlands
# 9   0.204545           UAE       Namibia
# 10  0.227273   West Indies       Ireland
# 11  0.250000      Scotland       Zimbave
# 12  0.272727   New Zealand     Australia
# ...

# %%
column='Score_of_first_innings'
df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Match_id        Team_1        Team_2  \
# 0   0.000000       Namibia     Sri Lanka
# 1   0.022727           UAE  Netherlands
# 2   0.045455      Scotland   West Indies
# 3   0.068182       Zimbave       Ireland
# 4   0.090909       Namibia  Netherlands
# 5   0.113636     Sri Lanka           UAE
# 6   0.136364      Scotland       Ireland
# 7   0.159091   West Indies       Zimbave
# 8   0.181818     Sri Lanka  Netherlands
# 9   0.204545           UAE       Namibia
# 10  0.227273   West Indies       Ireland
# 11  0.250000      Scotland       Zimbave
# 12  0.272727   New Zealand     Australia
# ...

# %%
column='Score_of_second_innings'
df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Match_id        Team_1        Team_2  \
# 0   0.000000       Namibia     Sri Lanka
# 1   0.022727           UAE  Netherlands
# 2   0.045455      Scotland   West Indies
# 3   0.068182       Zimbave       Ireland
# 4   0.090909       Namibia  Netherlands
# 5   0.113636     Sri Lanka           UAE
# 6   0.136364      Scotland       Ireland
# 7   0.159091   West Indies       Zimbave
# 8   0.181818     Sri Lanka  Netherlands
# 9   0.204545           UAE       Namibia
# 10  0.227273   West Indies       Ireland
# 11  0.250000      Scotland       Zimbave
# 12  0.272727   New Zealand     Australia
# ...

# %%
column='Wkts_in_first_innings'
df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Match_id        Team_1        Team_2  \
# 0   0.000000       Namibia     Sri Lanka
# 1   0.022727           UAE  Netherlands
# 2   0.045455      Scotland   West Indies
# 3   0.068182       Zimbave       Ireland
# 4   0.090909       Namibia  Netherlands
# 5   0.113636     Sri Lanka           UAE
# 6   0.136364      Scotland       Ireland
# 7   0.159091   West Indies       Zimbave
# 8   0.181818     Sri Lanka  Netherlands
# 9   0.204545           UAE       Namibia
# 10  0.227273   West Indies       Ireland
# 11  0.250000      Scotland       Zimbave
# 12  0.272727   New Zealand     Australia
# ...

# %%
column='Wkts_in_second_innings'
df1[column]=(df1[column]-df1[column].min())/(df1[column].max()-df1[column].min())
display(df1)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Match_id        Team_1        Team_2  \
# 0   0.000000       Namibia     Sri Lanka
# 1   0.022727           UAE  Netherlands
# 2   0.045455      Scotland   West Indies
# 3   0.068182       Zimbave       Ireland
# 4   0.090909       Namibia  Netherlands
# 5   0.113636     Sri Lanka           UAE
# 6   0.136364      Scotland       Ireland
# 7   0.159091   West Indies       Zimbave
# 8   0.181818     Sri Lanka  Netherlands
# 9   0.204545           UAE       Namibia
# 10  0.227273   West Indies       Ireland
# 11  0.250000      Scotland       Zimbave
# 12  0.272727   New Zealand     Australia
# ...
